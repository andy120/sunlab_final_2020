# %%
# Import libraries ---------------------------------------------------------------------------------------------------- #

import ipywidgets as widgets
from IPython.display import display, clear_output
import pickle

import sun2lab

maxrows = 10

style = {'description_width': '80px'}
layout_select ={'width': '110px', 'height': '100px' }
layout_text ={'width': '100px' }
layout_button ={'width': '110px' }
layout_combo ={'width': '120px' }

output = widgets.Output()

connect =sun2lab.sun2lab ()



#----------- Inputs ---------------------------------------------------------------------------------------#


Input_Select =  widgets.Select(options=['','', '','', ''],                            
                                                  value='',
                                                  
                                                  rows=maxrows,
                                                  style = style,
                                                  layout=layout_select,
                                                  disabled=False)
                                                                
     

selectinput= widgets.VBox([widgets.Label("Inputs:"),
                         Input_Select,
                  
                        ])

apply_getinput = widgets.Button(description='Get',
                                  disabled=False,
                                  button_style='info', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                  layout=layout_button,                      
                                  icon='')

apply_setinput = widgets.Button(description='Set',
                                  disabled=False,
                                  button_style='info', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                  layout=layout_button,  
                                  icon='')


apply_button= widgets.VBox([
                             apply_getinput,
                             apply_setinput
                            ])


def on_apply_get_input_clicked(b):

    if  measurement_id.value != "":
        connect_get=connect.get_unreserved_input() 
        selectedin=connect_get.groupby('TYPE').get_group('IN')
        if not selectedin.empty:

            Input_Select.options = [selectedin.index[0], selectedin.index[1], selectedin.index[2]]
            apply_getinput.button_style='success'
     
    else:
        with output:
            
            clear_output()
            print('Select USER id')
       
 #   with output:
        
              
  #     print(selectedinput.options)
                
    
apply_getinput.on_click(on_apply_get_input_clicked)


def on_apply_set_input_clicked(b):
    
    if Input_Select.value != "" and  measurement_id.value != "":
        connect.set_reserved_input(measurement_id.value, Input_Select.value)
        apply_setinput.button_style='success'
        
    else:
        with output:
            
            clear_output()
            print ("Please select user input")
       
        
        
       
        
apply_setinput.on_click(on_apply_set_input_clicked)


setup_inputs = widgets.VBox([
                         selectinput,  
                         apply_button,
                                             
                         ])

#...........................................Start................................................

apply_login = widgets.Button(description='Start',
                                  disabled=False,
                                  button_style='info', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                  layout=layout_button,                      
                                  icon='')


measurement_id = widgets.Dropdown(
                         options=['','USER1', 'USER2', 'USER3','USER4', 'USER5'],
                         value='',
                         layout=layout_combo,
                          disabled=False
                         )

login_text = widgets.Text(
    value='',
    layout=layout_text
    
)


loginstatus= widgets.VBox([widgets.Label("STATUS:"),
                         login_text,
                  
                        ])

def on_apply_login_clicked(b):
    
    
    if measurement_id.value == '':
        
        login_text.value = 'Select User'
        apply_login.button_style='warning'
       
        
    else:
       
        apply_login.button_style='success'
        login_text.value = 'Success'
               
        
    
apply_login.on_click(on_apply_login_clicked)


#..................................Connection........................................................................

apply_conn = widgets.Button(description='Conn',
                                  disabled=False,
                                  button_style='info', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                  layout=layout_button,  
                                  icon='')





timer_text = widgets.Text(
    value='',
    layout=layout_text
    
)


timerstatus= widgets.VBox([widgets.Label("TIMER:"),
                         timer_text,
                  
                        ])

def on_apply_conn_clicked(b):
    
    
    if  Input_Select.value !="" and selected_output.value != "":
    
           
        apply_conn.button_style='success' 
        my_list = [measurement_id.value, Input_Select.value,  
                                             select_device1.value, select_device2.value,
                                             selected_device3.value,  selected_device4.value, selected_output.value ]
        
      #  if (set([i for i in my_list if my_list.count(i)>1])) != "":

         #   for i in my_list:
          #      if my_list(i)>1:
                    
             #       apply_conn.button_style='warning'
                # apply_conn.disabled=True
            #else:
                
               # apply_conn.button_style='success'
                
        connect.set_reserved_conn(my_list[0], my_list[1],  
                                                 my_list[2], my_list[3],
                                                 my_list[4],  my_list[5], my_list[6] )    
            
                
               # print (set([i]))
                
                

       # for i in range (len (my_list) -1):
            
         #   try:
                
                

           #     if my_list[i] == my_list[i+1]:

              #      apply_conn.button_style='warning'
              #      apply_conn.disabled=True
              #      print (my_list[i])

              #  else:
                #    apply_conn.button_style='success'
                 #   connect.set_reserved_conn(my_list[0], my_list[1],  
                                              #   my_list[2], my_list[3],
                                               #  my_list[4],  my_list[5], my_list[6] )
           # except:
                
            
              #  print('Could not connect to socket')
            
            
   # else:
     #   with output:
            
        #    clear_output()
               
          #  print('Select INPUT')


            
apply_conn.on_click(on_apply_conn_clicked)


#........................................................................................................

apply_load = widgets.Button(description='Load',
                                  disabled=False,
                                  button_style='info', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                  layout=layout_button,  
                                  icon='')
apply_retrieve = widgets.Button(description='Retrieve',
                                  disabled=False,
                                  button_style='info', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                  layout=layout_button,  
                                  icon='')


def on_apply_load_clicked(b):
    
    apply_load.button_style='success' 
    path='./Connections/connections.pickle'
    my_list = [measurement_id.value, Input_Select.value,  
                                             select_device1.value, select_device2.value,
                                             selected_device3.value,  selected_device4.value, selected_output.value ]
    pickle_out = open(path, "wb") #Writing to pickle
    pickle.dump(my_list, pickle_out)
    pickle_out.close()

               
            
apply_load.on_click(on_apply_load_clicked)



def on_apply_retrieve_clicked(b):
    
    
    apply_retrieve.button_style='success' 
    path='./Connections/connections.pickle'
    pickle_in = open(path, "rb")
    device_Connections= pickle.load(pickle_in)
    print('Device_Connections:', device_Connections)
    measurement_id.value = device_Connections[0]
    Input_Select.options = [device_Connections[1]]
    select_device1.options = [device_Connections[2]]
    select_device2.options = [device_Connections[3]]
    selected_device3.options=[device_Connections[4]]
    selected_device4.options=[device_Connections[5]]
    selected_output.options = [device_Connections[6]]
    
               
        
    
apply_retrieve.on_click(on_apply_retrieve_clicked)






setup_conn = widgets.VBox([apply_conn,
                           apply_load,
                           apply_retrieve 
                         #  timerstatus
                          
                                                 
                         ])
#.................................Device1.................................................................

select_device1 =  widgets.Select(options=['',
                                             '',
                                             '',
                                             '',
                                             '',
                                             
                                            
                                                    ],
                                            value='',
                                            style = style,
                                            layout=layout_select,
                                            rows=maxrows,
                                            disabled=False)

select_dev1= widgets.VBox([widgets.Label("Device 1:"),
                             select_device1,
                      

                            ])


apply_dev1get = widgets.Button(description='Get',
                                  disabled=False,
                                  button_style='info', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                  layout=layout_button,                      
                                  icon='')

apply_dev1set= widgets.Button(description='Set',
                                  disabled=False,
                                  button_style='info', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                  layout=layout_button,  
                                  icon='')

setup_device1 = widgets.VBox([select_dev1,
                          apply_dev1get, 
                          apply_dev1set 
                                                 
                         ])



def on_apply_dev1_get1_clicked(b):
    
      
    
    if  Input_Select.value !="" and measurement_id.value != "":

        connect_get=connect.get_unreserved_input()
        selected_dev_1=connect_get.groupby('TYPE').get_group('AM')
        selectedattp=connect_get.groupby('TYPE').get_group('ATT')
        selectedspl=connect_get.groupby('TYPE').get_group('SPL')
        selectedwsp=connect_get.groupby('TYPE').get_group('WSP')
        select_device1.options = [selected_dev_1.index[0],   selected_dev_1.index[1],   selected_dev_1.index[2],   selected_dev_1.index[3],
                                         selectedattp.index[0],  selectedattp.index[1],
                                       #  selectedfil.index[0], selectedfil.index[1], selectedfil.index[2],  selectedfil.index[3], selectedfil.index[4],                           
                                        selectedspl.index[0], selectedspl.index[1],                           
                                         selectedwsp.index[0],  selectedwsp.index[1],                           

                                        ]

        apply_dev1get.button_style='success'
                         
     
      
    else:
        
        with output:

            clear_output()
            print('Select INPUT')


    
apply_dev1get.on_click(on_apply_dev1_get1_clicked)


def on_apply_dev1_set_clicked(b):
    
    
    if select_device1.value != "" and  measurement_id.value != "":
      connect.set_reserved_devs(measurement_id.value, select_device1.value)
      apply_dev1set.button_style='success'
        
    else:
        with output:
            
          clear_output()
          print ("Please select dev1")
       
 
        
apply_dev1set.on_click(on_apply_dev1_set_clicked)




#.....................................Device 2..........................................................................................

select_device2 =  widgets.Select(options=['',
                                                '',
                                                '',
                                                '',
                                                '',
                                                    ],
                                            value='',
                                            style = style,
                                              layout=layout_select,
                                            rows=maxrows,
                                            disabled=False)



select_dev2= widgets.VBox([widgets.Label("Device 2:"),
                             select_device2,
                           #  apply_attenuator,
                           #  Status_attenuator,

                            ])


apply_dev2get = widgets.Button(description='Get',
                                  disabled=False,
                                  button_style='info', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                  layout=layout_button,                      
                                  icon='')

apply_dev2set = widgets.Button(description='Set',
                                  disabled=False,
                                  button_style='info', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                  layout=layout_button,  
                                  icon='')

def on_apply_dev2_get_clicked(b):

    
    if  Input_Select.value !="" and measurement_id.value != "":

            
            
        connect_get=connect.get_unreserved_input()

        selected_dev_1=connect_get.groupby('TYPE').get_group('AM')
        selectedattp=connect_get.groupby('TYPE').get_group('ATT')
        selectedspl=connect_get.groupby('TYPE').get_group('SPL')
        selectedwsp=connect_get.groupby('TYPE').get_group('WSP')


        select_device2.options = [selected_dev_1.index[0],   selected_dev_1.index[1],   selected_dev_1.index[2],   selected_dev_1.index[3],
                                         selectedattp.index[0],  selectedattp.index[1],                                                         
                                        selectedspl.index[0], selectedspl.index[1],                           
                                         selectedwsp.index[0],  selectedwsp.index[1],                           

                                        ]
        apply_dev2get.button_style='success'
            
    else:
        
        with output:

            clear_output()
            print('Select INPUT')    
    
apply_dev2get.on_click(on_apply_dev2_get_clicked)



def on_apply_dev2_set_clicked(b):
    
           
    if select_device2.value != "" and  measurement_id.value != "":
        connect.set_reserved_devs(measurement_id.value, select_device2.value)
        apply_dev2set.button_style='success'
        
    else:
        with output:
                       
              clear_output()
              print ("Please select dev2")

   # connect.set_reserved_att(measurement_id.value, select_device2.value)

    #with output:
        
    #    print(connect.set_reserved_att(measurement_id.value, select_device2.value))
        
        
apply_dev2set.on_click(on_apply_dev2_set_clicked)


setup_device2 = widgets.VBox([
                          select_dev2,
                          apply_dev2get, 
                         apply_dev2set
                                                 
                         ])


#---------------------------------Device 3---------------------------------------------------------------


selected_device3 =  widgets.Select(options=['',
                                            '',
                                            '',
                                            '',
                                            '',
                                                    ],
                                            value='',
                                             style = style,
                                             layout=layout_select,
                                            rows=maxrows,
                                            disabled=False)


select_device3= widgets.VBox([widgets.Label("Device 3:"),
                             selected_device3,
                            # apply_filter,
                            # Status_filter

                            ])



apply_dev3get = widgets.Button(description='Get',
                                  disabled=False,
                                  button_style='info', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                  layout=layout_button,                      
                                  icon='')

apply_dev3set = widgets.Button(description='Set',
                                  disabled=False,
                                  button_style='info', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                  layout=layout_button,  
                                  icon='')




def on_apply_dev3_clicked(b):

    if  Input_Select.value !="" and measurement_id.value != "":
        
        connect_get=connect.get_unreserved_input()
        selectedamp=connect_get.groupby('TYPE').get_group('AM')
        selectedattp=connect_get.groupby('TYPE').get_group('ATT')
        selectedspl=connect_get.groupby('TYPE').get_group('SPL')
        selectedwsp=connect_get.groupby('TYPE').get_group('WSP')

        selected_device3.options =[selectedamp.index[0], selectedamp.index[1], selectedamp.index[2], selectedamp.index[3],
                                     selectedattp.index[0],  selectedattp.index[1],

                                    selectedspl.index[0], selectedspl.index[1],                           
                                     selectedwsp.index[0],  selectedwsp.index[1],                           

                                    ]
        
        apply_dev3get.button_style='success'
            
    else:
        
        with output:

            clear_output()
            print('Select INPUT')    
   
       
apply_dev3get.on_click(on_apply_dev3_clicked)





def on_apply_dev3_set_clicked(b):
    
   
           
    if selected_device3.value != "" and  measurement_id.value != "":
        connect.set_reserved_devs(measurement_id.value, selected_device3.value)
        apply_dev3set.button_style='success'
        
    else:
        with output:
                       
              clear_output()
              print ("Please select dev3")

   # connect.set_reserved_dev3(measurement_id.value, selected_device3.value)

   # with output:
        
     #   print(connect.set_reserved_dev3(measurement_id.value, selected_device3.value))
        
        
apply_dev3set.on_click(on_apply_dev3_set_clicked)


setup_dev3 = widgets.VBox([select_device3,
                         apply_dev3get, 
                         apply_dev3set
                                                 
                         ])



#---------------------------------Device 4---------------------------------------------------------------


selected_device4 =  widgets.Select(options=['',
                                            '',
                                            '',
                                            '',
                                            '',
                                                    ],
                                            value='',
                                             style = style,
                                             layout=layout_select,
                                            rows=maxrows,
                                            disabled=False)


select_device4= widgets.VBox([widgets.Label("Device 4:"),
                             selected_device4,
                            # apply_filter,
                            # Status_filter

                            ])



apply_dev4get = widgets.Button(description='Get',
                                  disabled=False,
                                  button_style='info', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                  layout=layout_button,                      
                                  icon='')

apply_dev4set = widgets.Button(description='Set',
                                  disabled=False,
                                  button_style='info', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                  layout=layout_button,  
                                  icon='')




def on_apply_dev4_clicked(b):
    
    
    if  Input_Select.value !="" and measurement_id.value != "":
        
        connect_get=connect.get_unreserved_input()
        selectedamp=connect_get.groupby('TYPE').get_group('AM')
        selectedattp=connect_get.groupby('TYPE').get_group('ATT')
        selectedspl=connect_get.groupby('TYPE').get_group('SPL')
        selectedwsp=connect_get.groupby('TYPE').get_group('WSP')

        selected_device4.options = [selectedamp.index[0], selectedamp.index[1], selectedamp.index[2], selectedamp.index[3],
                                     selectedattp.index[0],  selectedattp.index[1],                           
                                    selectedspl.index[0], selectedspl.index[1],                           
                                     selectedwsp.index[0],  selectedwsp.index[1],                           

                                    ]
    
        apply_dev4get.button_style='success'
            
    else:
        
        with output:

            clear_output()
            print('Select INPUT')    
   
    
    
apply_dev4get.on_click(on_apply_dev4_clicked)





def on_apply_dev4_set_clicked(b):
    
            
    if selected_device4.value != "" and  measurement_id.value != "":
        connect.set_reserved_devs(measurement_id.value, selected_device4.value)
        apply_dev4set.button_style='success'
        
    else:
        with output:
                       
              clear_output()
              print ("Please select dev4")        
        
apply_dev4set.on_click(on_apply_dev4_set_clicked)

setup_dev4 = widgets.VBox([select_device4,
                         apply_dev4get, 
                         apply_dev4set
                                                 
                         ])


#................................................................................................



selected_output =  widgets.Select(options=['',
                                                    '',
                                                    '',
                                                    '',
                                                    '',
                                                    ],
                                            value='',
                                            style = style,
                                             layout=layout_select,
                                            rows=maxrows,
                                            disabled=False)


select_output= widgets.VBox([widgets.Label("Outputs:"),
                             selected_output,
                          #   apply_filter,
                          #   Status_filter

                            ])


apply_getout = widgets.Button(description='Get',
                                  disabled=False,
                                  button_style='info', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                  layout=layout_button,                      
                                  icon='')

apply_setout = widgets.Button(description='Set',
                                  disabled=False,
                                  button_style='info', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                  layout=layout_button,  
                                  icon='')


def on_apply_out_clicked(b):
    
    if  Input_Select.value !="" and measurement_id.value != "":
        
        connect_get=connect.get_unreserved_input()
        selected_out =connect_get.groupby('TYPE').get_group('OUT')
        selected_output.options = [selected_out.index[0], selected_out.index[1], selected_out.index[2]]
        apply_getout.button_style='success'
            
    else:
        
        with output:

            clear_output()
            print('Select INPUT')    
      
        

apply_getout.on_click(on_apply_out_clicked)



def on_apply_out_set_clicked(b):
    
               
    if selected_output.value != "" and  measurement_id.value != "":
        connect.set_reserved_devs(measurement_id.value, selected_output.value)
        apply_setout.button_style='success'
        
    else:
        with output:
                       
              clear_output()
              print ("Please select output")  

        
apply_setout.on_click(on_apply_out_set_clicked)


setup_out = widgets.VBox([select_output,
                          apply_getout, 
                         apply_setout
                                                 
                         ])

#............................................................................................

setuptab = widgets.HBox([#measurement_id,
                        # apply_login
                         setup_inputs,
                         setup_device1,
                         setup_device2 ,                      
                        setup_dev3 ,
                        setup_dev4,
                        setup_out,
                       setup_conn
    
                        ])


#.....................................................................................................................


userstab = widgets.VBox([measurement_id,
                         apply_login,
                         loginstatus
                        
                        ])

                     
tab = widgets.Tab()

tabnames = ["Users",
            "Resources",
        
           
         ]


tabs = [userstab, setuptab]
tab.children = tabs

for i in range(len(tabnames)):
    
    tab.set_title(i, str(tabnames[i]))



tab
# Out:
# Initialising Lab ...
# Initialising Optical Switch
# Initialising Optical Switch with Hostname:  192.168.0.2
# Port:  830
# Username:  admin
# Password:  root
#
# Laboratory successfully initialised.
# ...
#        USER PORT_INPUT PORT_OUTPUT TYPE
# TLS    None       None           1   IN
# ODF1  USER1       None           2   IN
# ODF2   None       None           3   IN
# PRE1   None         19           6   AM
# PRE2   None         20           7   AM
# BOO1   None         21           8   AM
# BOO2   None         22           9   AM
# VOA1   None         17           4  ATT
# VOA2   None         18           5  ATT
# SPL1   None         25          12  SPL
# SPL2   None         26          13  SPL
# WSS1   None         23          10  WSP
# WSS2   None         24          11  WSP
# PMR1   None         27        None  OUT
# PMR2   None         28        None  OUT
# OMA    None         29        None  OUT
#        USER PORT_INPUT PORT_OUTPUT TYPE
# TLS    None       None           1   IN
# ...
