# %%
# Import libraries ---------------------------------------------------------------------------------------------------- #
import ipywidgets as widgets
from IPython.display import display, clear_output
import ApexRemoteControl as arc
import WSRemoteControl as ws
#import sun2lab

maxrows = 20


output = widgets.Output()

# Start SLOT1 Tab----------------------------------------------------------------------------#

# Define the widgets and their callbacks

# Text box to hold PowerSet
arc.Slot1PowerSetBFT =  widgets.BoundedFloatText(
                        value= -21.0,
                         min=-21.0,
                         max=13.0,
                         step=1,
                         description='Set Power (dBm):',
                         disabled=False,
                         style={'description_width': 'initial'}
                         )

# Text box to hold PowerGet
arc.Slot1PowerGetBFT =  widgets.BoundedFloatText(
                        value= 0,
                         min=-21.0,
                         max=13.0,
                         step=1,
                         description='Power Measured (dBm):',
                         disabled=False,
                         style={'description_width': 'initial'}
                         )


# Button to SET the Power
arc.Slot1PowerSetButton = widgets.Button(description='Set',
                                  disabled=False,
                                  button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                 # layout=layout_button,                      
                                  icon='')
arc.Slot1PowerSetButton.on_click(arc.apex_tls_pset)




# Button to get the Power Value
arc.Slot1PowerGetButton = widgets.Button(description='Get',
                                  disabled=False,
                                  button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                 # layout=layout_button,                      
                                  icon='')
arc.Slot1PowerGetButton.on_click(arc.apex_tls_pget)


# Text box to Set Wavelength
arc.Slot1WavelenSetBFT =  widgets.BoundedFloatText(
                        value= 1526,
                         min= 1526,
                         max=1610,
                         step=1,
                         description='Set Wavelength (nm):',
                         disabled=False,
                         style={'description_width': 'initial'}
                         )


# Text box to hold Wavelength GET
arc.Slot1WavelenGetBFT =  widgets.BoundedFloatText(
                        value= 0,
                         min=1480,
                         max=1610,
                         step=1,
                         description='Measured Wavelength (nm):',
                         disabled=False,
                         style={'description_width': 'initial'}
                         )


# Button to SET the Wavelength
arc.Slot1WavelenSetButton = widgets.Button(description='Set',
                                  disabled=False,
                                  button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                 # layout=layout_button,                      
                                  icon='')
arc.Slot1WavelenSetButton.on_click(arc.apex_tls_wset)




# Button to GET the Wavelength
arc.Slot1WavelenGetButton = widgets.Button(description='Get',
                                  disabled=False,
                                  button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                 # layout=layout_button,                      
                                  icon='')
arc.Slot1WavelenGetButton.on_click(arc.apex_tls_wget)



# Button to turn the LASER ON
arc.Slot1LaserOnButton = widgets.Button(description='Laser On',
                                  disabled=False,
                                  button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                 # layout=layout_button,                      
                                  icon='')
arc.Slot1LaserOnButton.on_click(arc.apex_tls_laseron)

# Button to turn the LASER OFF
arc.Slot1LaserOffButton = widgets.Button(description='Laser Off',
                                  disabled=False,
                                  button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                 # layout=layout_button,                      
                                  icon='check')
arc.Slot1LaserOffButton.on_click(arc.apex_tls_laseroff)

       
   

SLOT1 = widgets.VBox([widgets.Label("Tunable Laser Source Parameters:"),
                      widgets.HBox([arc.Slot1WavelenSetBFT, arc.Slot1WavelenSetButton]),                                                                     
                      widgets.HBox([arc.Slot1WavelenGetBFT, arc.Slot1WavelenGetButton]),
                      widgets.HBox([arc.Slot1PowerSetBFT, arc.Slot1PowerSetButton]),                                                                     
                      widgets.HBox([arc.Slot1PowerGetBFT, arc.Slot1PowerGetButton]),
                      widgets.HBox([arc.Slot1LaserOnButton, arc.Slot1LaserOffButton])])



# Start SLOT2 Tab----------------------------------------------------------------------------#

arc.Slot2OAT1SetBFT =  widgets.BoundedFloatText(
                        value= 0.0,
                         min=0.0,
                         max=30.0,
                         step=1,
                         description='Set Attenuation (dB):',
                         disabled=False,
                         style={'description_width': 'initial'}
                         )


arc.Slot2OAT1SetButton = widgets.Button(description='Set',
                                  disabled=False,
                                  button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                 # layout=layout_button,                      
                                  icon='')

arc.Slot2OAT1SetButton.on_click(arc.apex_attn1_set)

arc.Slot2OAT1GetBFT =  widgets.BoundedFloatText(
                        value= 0.0,
                         min=0.0,
                         max=30.0,
                         step=1,
                         description='Measured Attenuation (dB):',
                         disabled=False,
                         style={'description_width': 'initial'}
                         )


arc.Slot2OAT1GetButton = widgets.Button(description='Get',
                                  disabled=False,
                                  button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                 # layout=layout_button,                      
                                  icon='')
   
arc.Slot2OAT1GetButton.on_click(arc.apex_attn1_get)  


arc.Slot2OAT2SetBFT =  widgets.BoundedFloatText(
                        value= 0.0,
                         min=0.0,
                         max=30.0,
                         step=1,
                         description='Set Attenuation (dB):',
                         disabled=False,
                         style={'description_width': 'initial'}
                         )


arc.Slot2OAT2SetButton = widgets.Button(description='Set',
                                  disabled=False,
                                  button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                 # layout=layout_button,                      
                                  icon='')

arc.Slot2OAT2SetButton.on_click(arc.apex_attn2_set)

arc.Slot2OAT2GetBFT =  widgets.BoundedFloatText(
                        value= 0.0,
                         min=0.0,
                         max=30.0,
                         step=1,
                         description='Measured Attenuation (dB):',
                         disabled=False,
                         style={'description_width': 'initial'}
                         )


arc.Slot2OAT2GetButton = widgets.Button(description='Get',
                                  disabled=False,
                                  button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                 # layout=layout_button,                      
                                  icon='')
   
arc.Slot2OAT2GetButton.on_click(arc.apex_attn2_get)





SLOT2 = widgets.VBox([widgets.Label("Set Attenuator Channel #1 Parameter:"),
                      widgets.HBox([arc.Slot2OAT1SetBFT, arc.Slot2OAT1SetButton]),
                      widgets.HBox([arc.Slot2OAT1GetBFT, arc.Slot2OAT1GetButton]),
                      widgets.Label("Set Attenuator Channel #2 Parameter:"),
                      widgets.HBox([arc.Slot2OAT2SetBFT, arc.Slot2OAT2SetButton]),
                      widgets.HBox([arc.Slot2OAT2GetBFT, arc.Slot2OAT2GetButton])])


#............SLOT3.................................................................................................................


arc.Slot3ManModeButton = widgets.Button(description='MANUAL MODE',
                                  disabled=False,
                                  button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                 # layout=layout_button,
                                  icon='check')
arc.Slot3ManModeButton.on_click(arc.apex_efda1_manmode)

arc.Slot3AutoPowerModeButton = widgets.Button(description='AUTO PWR MODE',
                                  disabled=False,
                                  button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                 # layout=layout_button,                      
                                  icon='')
arc.Slot3AutoPowerModeButton.on_click(arc.apex_efda1_apmode)


arc.Slot3CurrentSetBFT =  widgets.BoundedFloatText(
                        value= 10,
                         min=0,
                         max=100,
                         step=1,
                         description='Pump Current (mA):',
                         disabled=False,
                         style={'description_width': 'initial'}
                         )

arc.Slot3CurrentSetButton = widgets.Button(description='Set',
                                  disabled=False,
                                  button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                 # layout=layout_button,
                                  icon='')
arc.Slot3CurrentSetButton.on_click(arc.apex_efda1_iset)



arc.Slot3PowerSetBFT =  widgets.BoundedFloatText(
                        value= -30.0,
                         min=-80.0,
                         max=13.0,
                         step=1,
                         description='Setpoint for Power (dBm):',
                         disabled=False,
                         style={'description_width': 'initial'}
                         )


arc.Slot3PowerGetBFT=  widgets.BoundedFloatText(
                         value = -80.0,
                         min=-80.0,
                         max=40.0,
                         step=1,
                         description='Measured Power (dBm):',
                         disabled=False,
                         style={'description_width': 'initial'}
                         )



arc.Slot3PowerSetButton = widgets.Button(description='Set',
                                  disabled=False,
                                  button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                 # layout=layout_button,                      
                                  icon='')
arc.Slot3PowerSetButton.on_click(arc.apex_efda1_pset)



arc.Slot3PowerGetButton = widgets.Button(description='Get',
                                  disabled=False,
                                  button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                  # layout=layout_button,                      
                                  icon='')
      
arc.Slot3PowerGetButton.on_click(arc.apex_efda1_get)


arc.Slot3AmpOnButton = widgets.Button(description='EFDA ON',
                                  disabled=False,
                                  button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                  # layout=layout_button,                      
                                  icon='')
      
arc.Slot3AmpOnButton.on_click(arc.apex_efda1_on)

arc.Slot3AmpOffButton = widgets.Button(description='EFDA OFF',
                                  disabled=False,
                                  button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                  # layout=layout_button,                      
                                  icon='')
      
arc.Slot3AmpOffButton.on_click(arc.apex_efda1_off)



SLOT3 = widgets.VBox([widgets.Label("Erbium Fibre Doped Amplifier #1 Parameters:"),
                      widgets.HBox([arc.Slot3ManModeButton, arc.Slot3AutoPowerModeButton]),
                      widgets.HBox([arc.Slot3CurrentSetBFT, arc.Slot3CurrentSetButton]), 
                      widgets.HBox([arc.Slot3PowerSetBFT, arc.Slot3PowerSetButton]),
                      widgets.HBox([arc.Slot3PowerGetBFT, arc.Slot3PowerGetButton]),
                      widgets.HBox([arc.Slot3AmpOnButton, arc.Slot3AmpOffButton])])


#.................SLOT4..........................................................................................................

arc.Slot4ManModeButton = widgets.Button(description='MANUAL MODE',
                                  disabled=False,
                                  button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                 # layout=layout_button,
                                  icon='check')
arc.Slot4ManModeButton.on_click(arc.apex_efda2_manmode)

arc.Slot4AutoPowerModeButton = widgets.Button(description='AUTO PWR MODE',
                                  disabled=False,
                                  button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                 # layout=layout_button,                      
                                  icon='')
arc.Slot4AutoPowerModeButton.on_click(arc.apex_efda2_apmode)



arc.Slot4CurrentSetBFT =  widgets.BoundedFloatText(
                        value= 10,
                         min=0,
                         max=100,
                         step=1,
                         description='Pump Current (mA):',
                         disabled=False,
                         style={'description_width': 'initial'}
                         )




arc.Slot4CurrentSetButton = widgets.Button(description='Set',
                                  disabled=False,
                                  button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                 # layout=layout_button,
                                  icon='')
arc.Slot4CurrentSetButton.on_click(arc.apex_efda2_iset)



arc.Slot4PowerSetBFT =  widgets.BoundedFloatText(
                        value= -30.0,
                         min=-80.0,
                         max=13.0,
                         step=1,
                         description='Setpoint for Power (dBm):',
                         disabled=False,
                         style={'description_width': 'initial'}
                         )


arc.Slot4PowerGetBFT=  widgets.BoundedFloatText(
                         value = -80.0,
                         min=-80.0,
                         max=40.0,
                         step=1,
                         description='Measured Power (dBm):',
                         disabled=False,
                         style={'description_width': 'initial'}
                         )



arc.Slot4PowerSetButton = widgets.Button(description='Set',
                                  disabled=False,
                                  button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                 # layout=layout_button,                      
                                  icon='')
arc.Slot4PowerSetButton.on_click(arc.apex_efda2_pset)



arc.Slot4PowerGetButton = widgets.Button(description='Get',
                                  disabled=False,
                                  button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                  # layout=layout_button,                      
                                  icon='')
      
arc.Slot4PowerGetButton.on_click(arc.apex_efda2_get)


arc.Slot4AmpOnButton = widgets.Button(description='EFDA ON',
                                  disabled=False,
                                  button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                  # layout=layout_button,                      
                                  icon='')
      
arc.Slot4AmpOnButton.on_click(arc.apex_efda2_on)

arc.Slot4AmpOffButton = widgets.Button(description='EFDA OFF',
                                  disabled=False,
                                  button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                  # layout=layout_button,                      
                                  icon='')
      
arc.Slot4AmpOffButton.on_click(arc.apex_efda2_off)



SLOT4 = widgets.VBox([widgets.Label("Erbium Fibre Doped Amplifier #2 Parameters:"),
                      widgets.HBox([arc.Slot4ManModeButton, arc.Slot4AutoPowerModeButton]),
                      widgets.HBox([arc.Slot4CurrentSetBFT, arc.Slot4CurrentSetButton]), 
                      widgets.HBox([arc.Slot4PowerSetBFT, arc.Slot4PowerSetButton]),
                      widgets.HBox([arc.Slot4PowerGetBFT, arc.Slot4PowerGetButton]),
                      widgets.HBox([arc.Slot4AmpOnButton, arc.Slot4AmpOffButton])])

#...................SLOT5......................................................................................................

arc.Slot5ManModeButton = widgets.Button(description='MANUAL MODE',
                                  disabled=False,
                                  button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                 # layout=layout_button,                      
                                  icon='check')
arc.Slot5ManModeButton.on_click(arc.apex_efdba1_manmode)

arc.Slot5AutoPowerModeButton = widgets.Button(description='AUTO PWR MODE',
                                  disabled=False,
                                  button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                 # layout=layout_button,                      
                                  icon='')
arc.Slot5AutoPowerModeButton.on_click(arc.apex_efdba1_apmode)


arc.Slot5CurrentSetBFT =  widgets.BoundedFloatText(
                        value= 10,
                         min=0,
                         max=100,
                         step=1,
                         description='Pump Current (mA):',
                         disabled=False,
                         style={'description_width': 'initial'}
                         )

arc.Slot5CurrentSetButton = widgets.Button(description='Set',
                                  disabled=False,
                                  button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                 # layout=layout_button,                      
                                  icon='')
arc.Slot5CurrentSetButton.on_click(arc.apex_efdba1_iset)



arc.Slot5PowerSetBFT =  widgets.BoundedFloatText(
                        value= -30.0,
                         min=-80.0,
                         max=13.0,
                         step=1,
                         description='Setpoint for Power (dBm):',
                         disabled=False,
                         style={'description_width': 'initial'}
                         )


arc.Slot5PowerGetBFT=  widgets.BoundedFloatText(
                         value = -80.0,
                         min=-80.0,
                         max=40.0,
                         step=1,
                         description='Measured Power (dBm):',
                         disabled=False,
                         style={'description_width': 'initial'}
                         )



arc.Slot5PowerSetButton = widgets.Button(description='Set',
                                  disabled=False,
                                  button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                 # layout=layout_button,                      
                                  icon='')
arc.Slot5PowerSetButton.on_click(arc.apex_efdba1_pset)



arc.Slot5PowerGetButton = widgets.Button(description='Get',
                                  disabled=False,
                                  button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                  # layout=layout_button,                      
                                  icon='')
      
arc.Slot5PowerGetButton.on_click(arc.apex_efdba1_get)


arc.Slot5AmpOnButton = widgets.Button(description='EFDA ON',
                                  disabled=False,
                                  button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                  # layout=layout_button,                      
                                  icon='')
      
arc.Slot5AmpOnButton.on_click(arc.apex_efdba1_on)

arc.Slot5AmpOffButton = widgets.Button(description='EFDA OFF',
                                  disabled=False,
                                  button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                  # layout=layout_button,                      
                                  icon='')
      
arc.Slot5AmpOffButton.on_click(arc.apex_efdba1_off)



SLOT5 = widgets.VBox([widgets.Label("Erbium Fibre Doped Booster Amplifier #1 Parameters:"),
                      widgets.HBox([arc.Slot5ManModeButton, arc.Slot5AutoPowerModeButton]),
                      widgets.HBox([arc.Slot5CurrentSetBFT, arc.Slot5CurrentSetButton]), 
                      widgets.HBox([arc.Slot5PowerSetBFT, arc.Slot5PowerSetButton]),
                      widgets.HBox([arc.Slot5PowerGetBFT, arc.Slot5PowerGetButton]),
                      widgets.HBox([arc.Slot5AmpOnButton, arc.Slot5AmpOffButton])])



    

#......................SLOT6..................................................................................................


arc.Slot6ManModeButton = widgets.Button(description='MANUAL MODE',
                                  disabled=False,
                                  button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                 # layout=layout_button,                      
                                  icon='check')
arc.Slot6ManModeButton.on_click(arc.apex_efdba2_manmode)

arc.Slot6AutoPowerModeButton = widgets.Button(description='AUTO PWR MODE',
                                  disabled=False,
                                  button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                 # layout=layout_button,                      
                                  icon='')
arc.Slot6AutoPowerModeButton.on_click(arc.apex_efdba2_apmode)


arc.Slot6CurrentSetBFT =  widgets.BoundedFloatText(
                        value= 10,
                         min=0,
                         max=100,
                         step=1,
                         description='Pump Current (mA):',
                         disabled=False,
                         style={'description_width': 'initial'}
                         )

arc.Slot6CurrentSetButton = widgets.Button(description='Set',
                                  disabled=False,
                                  button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                 # layout=layout_button,                      
                                  icon='')
arc.Slot6CurrentSetButton.on_click(arc.apex_efdba2_iset)



arc.Slot6PowerSetBFT =  widgets.BoundedFloatText(
                        value= -30.0,
                         min=-80.0,
                         max=13.0,
                         step=1,
                         description='Setpoint for Power (dBm):',
                         disabled=False,
                         style={'description_width': 'initial'}
                         )


arc.Slot6PowerGetBFT=  widgets.BoundedFloatText(
                         value = -80.0,
                         min=-80.0,
                         max=40.0,
                         step=1,
                         description='Measured Power (dBm):',
                         disabled=False,
                         style={'description_width': 'initial'}
                         )



arc.Slot6PowerSetButton = widgets.Button(description='Set',
                                  disabled=False,
                                  button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                 # layout=layout_button,                      
                                  icon='')
arc.Slot6PowerSetButton.on_click(arc.apex_efdba2_pset)



arc.Slot6PowerGetButton = widgets.Button(description='Get',
                                  disabled=False,
                                  button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                  # layout=layout_button,                      
                                  icon='')
      
arc.Slot6PowerGetButton.on_click(arc.apex_efdba2_get)


arc.Slot6AmpOnButton = widgets.Button(description='EFDA ON',
                                  disabled=False,
                                  button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                  # layout=layout_button,                      
                                  icon='')
      
arc.Slot6AmpOnButton.on_click(arc.apex_efdba2_on)

arc.Slot6AmpOffButton = widgets.Button(description='EFDA OFF',
                                  disabled=False,
                                  button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                  # layout=layout_button,                      
                                  icon='')
      
arc.Slot6AmpOffButton.on_click(arc.apex_efdba2_off)



SLOT6 = widgets.VBox([widgets.Label("Erbium Fibre Doped Booster Amplifier #2 Parameters:"),
                      widgets.HBox([arc.Slot6ManModeButton, arc.Slot6AutoPowerModeButton]),
                      widgets.HBox([arc.Slot6CurrentSetBFT, arc.Slot6CurrentSetButton]), 
                      widgets.HBox([arc.Slot6PowerSetBFT, arc.Slot6PowerSetButton]),
                      widgets.HBox([arc.Slot6PowerGetBFT, arc.Slot6PowerGetButton]),
                      widgets.HBox([arc.Slot6AmpOnButton, arc.Slot6AmpOffButton])])


#............SLOT7.........................................................................................

arc.Slot7PowerCh1BFT =  widgets.BoundedFloatText(
                        value= -80.0,
                         min=-80.0,
                         max=33.0,
                         step=1,
                         description='Channel #1 Power (dBm):',
                         disabled=False,
                         style={'description_width': 'initial'}    
                         )



arc.Slot7GetPowerCh1Button = widgets.Button(description='Get',
                                  disabled=False,
                                  button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                 # layout=layout_button,                      
                                  icon='')

arc.Slot7GetPowerCh1Button.on_click(arc.apex_opa1_get)



arc.Slot7PowerCh2BFT =  widgets.BoundedFloatText(
                        value= -80.0,
                         min=-80.0,
                         max=33.0,
                         step=1,
                         description='Channel #2 Power (dBm):',
                         disabled=False,
                         style={'description_width': 'initial'}    
                         )



arc.Slot7GetPowerCh2Button = widgets.Button(description='Get',
                                  disabled=False,
                                  button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                  tooltip='Click to select Input',
                                 # layout=layout_button,                      
                                  icon='')
arc.Slot7GetPowerCh2Button.on_click(arc.apex_opa2_get)
            



SLOT7 = widgets.HBox([widgets.VBox([widgets.Label("Measure Power Using Optical Power Meter:"),
                                   widgets.HBox([arc.Slot7PowerCh1BFT, arc.Slot7GetPowerCh1Button]),
                                   widgets.HBox([arc.Slot7PowerCh2BFT, arc.Slot7GetPowerCh2Button])]),
                    widgets.Output(layout={'border': '1px solid black'})])
    




#........SAVE and LOAD APEX CONFIG ..........................................................................................

arc.FilenameText = widgets.Text(value='',
                                placeholder='Type NEW filename',
                                description='Filename:',
                                disabled=False)

arc.SaveConfigButton = widgets.Button(description='Save Configuration',
                                      disabled=False,
                                      button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                      tooltip='Click to select Input',
                                    # layout=layout_button,                      
                                      icon='',
                                      style={'description_width': 'initial'},
                                     layout={'width': 'max-content'})

arc.SaveConfigButton.on_click(arc.apex_save_to_disk)

arc.ListConfigButton = widgets.Button(description='List Configurations',
                                      disabled=False,
                                      button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                      tooltip='Click to select Input',
                                    # layout=layout_button,                      
                                      icon='',
                                      style={'description_width': 'initial'},
                                     layout={'width': 'max-content'})

arc.ListConfigButton.on_click(arc.apex_list_config)

arc.ListConfigSelect = widgets.Select(rows=6, disabled=False )


arc.LoadConfigButton = widgets.Button(description='Load Configuration',
                                      disabled=False,
                                      button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                      tooltip='Click to select Input',
                                    # layout=layout_button,                      
                                      icon='',
                                      style={'description_width': 'initial'},
                                     layout={'width': 'max-content'})

arc.LoadConfigButton.on_click(arc.apex_load_from_disk)

SAVE_LOAD_APEX = widgets.VBox([widgets.Label("Save and/or Load a configuration to disk:"),
                               widgets.HBox([arc.ListConfigButton,arc.LoadConfigButton]),
                               arc.ListConfigSelect,
                               widgets.HBox([arc.FilenameText,arc.SaveConfigButton])])

#............................................................................................................................

#........SAVE and LOAD Waveshaper CONFIG ..........................................................................................

ws.WSFilenameText = widgets.Text(value='',
                                 placeholder='Type a NEW filename',
                                 description='NEW Filename:',
                                 disabled=False,
                                 layout={'width': 'max-content'},
                                style={'description_width': 'initial'})

ws.WSSaveConfig1Button = widgets.Button(description='Save WS#1 Config to File',
                                      disabled=False,
                                      button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                      tooltip='Click to select Input',
                                    # layout=layout_button,                      
                                      icon='',
                                      style={'description_width': 'initial'},
                                     layout={'width': 'max-content'})

ws.WSSaveConfig1Button.on_click(ws.ws1_save_to_disk)

ws.WSSaveConfig2Button = widgets.Button(description='Save WS #2 Config to File',
                                      disabled=False,
                                      button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                      tooltip='Click to select Input',
                                    # layout=layout_button,                      
                                      icon='',
                                      style={'description_width': 'initial'},
                                     layout={'width': 'max-content'})

ws.WSSaveConfig2Button.on_click(ws.ws2_save_to_disk)

ws.WSListConfigButton = widgets.Button(description='List Configurations',
                                      disabled=False,
                                      button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                      tooltip='Click to select Input',
                                    # layout=layout_button,                      
                                      icon='',
                                      style={'description_width': 'initial'},
                                     layout={'width': 'max-content'})

ws.WSListConfigButton.on_click(ws.ws_list_config)


ws.WSLoadConfig1Button = widgets.Button(description='Load Config to WS#1',
                                      disabled=False,
                                      button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                      tooltip='Click to select Input',
                                    # layout=layout_button,                      
                                      icon='',
                                      style={'description_width': 'initial'},
                                     layout={'width': 'max-content'})

ws.WSLoadConfig1Button.on_click(ws.ws_load1_from_disk)

ws.WSLoadConfig2Button = widgets.Button(description='Load Config to WS#2',
                                      disabled=False,
                                      button_style='success', # 'success', 'info', 'warning', 'danger' or ''
                                      tooltip='Click to select Input',
                                    # layout=layout_button,                      
                                      icon='',
                                      style={'description_width': 'initial'},
                                     layout={'width': 'max-content'})

ws.WSLoadConfig2Button.on_click(ws.ws_load2_from_disk)

ws.WSListConfigSelect = widgets.Select(rows=6, disabled=False )

SAVE_LOAD_WS = widgets.VBox([widgets.Label("Save and/or Load a configuration to disk:"),
                             widgets.HBox([ws.WSLoadConfig1Button, ws.WSLoadConfig2Button]),
                             widgets.HBox([ws.WSListConfigSelect,ws.WSListConfigButton]),
                             ws.WSFilenameText,
                             widgets.HBox([ws.WSSaveConfig1Button,ws.WSSaveConfig2Button])])

#............................................................................................................................



tab = widgets.Tab()

tabnames = ["SL1: TLS",
            "SL2: VOA",
            "SL3: PRE #1",
            "SL4: PRE #2",
            "SL5: BOO #1",
            "SL6: BOO #2",
            "SL7: OPM",
            "Save/Load APEX",
            "Save/Load WS"
           ]




tabs = [SLOT1, SLOT2, SLOT3, SLOT4, SLOT5, SLOT6, SLOT7, SAVE_LOAD_APEX, SAVE_LOAD_WS]
tab.children = tabs

for i in range(len(tabnames)):
    
    tab.set_title(i, str(tabnames[i]))
    

tab
# Out:
# ...
# Slot1WavelenSetBFT.value =  1610.0
# Slot1PowerSetBFT.value =  13.0
# Slot2OAT1SetBFT.value =  30.0
# Slot2OAT2SetBFT.value =  30.0
# Slot3PowerSetBFT.value =  13.0
# Slot3CurrentSetBFT.value =  100.0
# Slot4PowerSetBFT.value =  13.0
# Slot4CurrentSetBFT.value =  100.0
# Slot5PowerSetBFT.value =  13.0
# Slot5CurrentSetBFT.value =  100.0
# Slot6PowerSetBFT.value =  13.0
# Slot6CurrentSetBFT.value =  100.0
